# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Usuario\\Desktop\\the bridge\\github\\2603_ds_sql_thebridge\\Practica\\3-Proyecto'

# %% [markdown]
# ### 1. LOAD
#    - Concatenated 4 class CSVs into df_students
#    - Loaded claustro.csv into df_faculty

# %%
# we load all of the class CSVs and stack them into just one dataframe

df_students = pd.concat([
    pd.read_csv("data/clase_1.csv", sep = ";"),
    pd.read_csv("data/clase_2.csv", sep = ";"),
    pd.read_csv("data/clase_3.csv", sep = ";"),
    pd.read_csv("data/clase_4.csv", sep = ";")

], ignore_index=True)

# %%
# load faculty CSV separately (different structure)

df_faculty = pd.read_csv("data/claustro.csv", sep=";")

# %% [markdown]
# ### 2. CLEAN
#    - Fixed typo (FullSatck → FullStack)
#    - Melted project columns from wide → long format (df_melted)
#    - Dropped NaN rows (260 real grades remaining)

# %%
# 9 columns were expected but we got 15 instead 

print(df_students.shape)
print(df_faculty.shape)
# Out:
# (52, 15)
# (10, 6)

# %%
# the 15 columns are due to the 10 projects that there are (5 for DS and 5 for FS)

print(df_students.columns.tolist())
# Out:
# ['Nombre', 'Email', 'Promoción', 'Fecha_comienzo', 'Campus', 'Proyecto_HLF', 'Proyecto_EDA', 'Proyecto_BBDD', 'Proyecto_ML', 'Proyecto_Deployment', 'Proyecto_WebDev', 'Proyecto_FrontEnd', 'Proyecto_Backend', 'Proyecto_React', 'Proyecto_FullSatck']

# %%
# 1st we see what the data looks like

df_students.head(2)
# Out:
#              Nombre                       Email   Promoción Fecha_comienzo  \
# 0      Jafet Casals      Jafet_Casals@gmail.com  Septiembre     18/09/2023
# 1  Jorge Manzanares  Jorge_Manzanares@gmail.com  Septiembre     18/09/2023
#
#    Campus Proyecto_HLF Proyecto_EDA Proyecto_BBDD Proyecto_ML  \
# 0  Madrid         Apto      No Apto          Apto        Apto
# 1  Madrid         Apto      No Apto          Apto        Apto
#
#   Proyecto_Deployment Proyecto_WebDev Proyecto_FrontEnd Proyecto_Backend  \
# 0                Apto             NaN               NaN              NaN
# 1                Apto             NaN               NaN              NaN
#
#   Proyecto_React Proyecto_FullSatck
# 0            NaN                NaN
# 1            NaN                NaN

# %%
# we correct the typo on the column named "Proyecto_FullSatck"

df_students = df_students.rename(columns = {"Proyecto_FullSatck": "Proyecto_FullStack"})

# %%
# 2nd we see how many null values in each column of our dataframe
# null values != missing data // those students just belong to another "vertical"
# 27 nulls on DS projects = FS students
# 25 nulls on FS projects = DS students

print(df_students.isnull().sum())
# Out:
# Nombre                  0
# Email                   0
# Promoción               0
# Fecha_comienzo          0
# Campus                  0
# Proyecto_HLF           27
# Proyecto_EDA           27
# Proyecto_BBDD          27
# Proyecto_ML            27
# Proyecto_Deployment    27
# Proyecto_WebDev        25
# Proyecto_FrontEnd      25
# Proyecto_Backend       25
# Proyecto_React         25
# Proyecto_FullStack     25
# dtype: int64

# %%
# we create a list of the columns that we want to convert into rows 

project_columns = [
    
    "Proyecto_HLF", "Proyecto_EDA", "Proyecto_BBDD", "Proyecto_ML", 
    "Proyecto_Deployment", "Proyecto_WebDev", "Proyecto_FrontEnd", 
    "Proyecto_Backend", "Proyecto_React", "Proyecto_FullStack"
]

# %%
df_melted = df_students.melt( # df_students.melt() — we're calling the melt function -> transforms the datafarme from wide to long format
    
    id_vars = ["Nombre", "Email", "Promoción", "Fecha_comienzo", "Campus"], # id_vars = [...] -> these are the columns we want to keep as-is
    
    value_vars = project_columns, # value_vars = project_columns -> these are the columns we wanto to convert into rows // instead of 10 project columns, each project becomes its own row
   
    var_name = "tipo_proyecto", # var_name = "tipo_proyecto" -> this is the name we give to the new column that stores the project column names (i.e, "Projecto_EDA")
   
    value_name = "resultado" # value_name = "resultado" -> this is the name we give to the new column that stores the values (Apto // No Apto)
)

# %%
df_melted.head(5)
# Out:
#              Nombre                       Email   Promoción Fecha_comienzo  \
# 0      Jafet Casals      Jafet_Casals@gmail.com  Septiembre     18/09/2023
# 1  Jorge Manzanares  Jorge_Manzanares@gmail.com  Septiembre     18/09/2023
# 2     Onofre Adadia     Onofre_Adadia@gmail.com  Septiembre     18/09/2023
# 3      Merche Prada      Merche_Prada@gmail.com  Septiembre     18/09/2023
# 4      Pilar Abella      Pilar_Abella@gmail.com  Septiembre     18/09/2023
#
#    Campus tipo_proyecto resultado
# 0  Madrid  Proyecto_HLF      Apto
# 1  Madrid  Proyecto_HLF      Apto
# 2  Madrid  Proyecto_HLF      Apto
# 3  Madrid  Proyecto_HLF      Apto
# 4  Madrid  Proyecto_HLF      Apto

# %%
# we need to drop the NULL values since they don't represent real grades 

df_melted = df_melted.dropna(subset = ["resultado"])

print(df_melted.shape)
# Out:
# (260, 7)

# %%
df_melted
# Out:
#                   Nombre                          Email   Promoción  \
# 0           Jafet Casals         Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares     Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia        Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada         Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella         Pilar_Abella@gmail.com  Septiembre
# ..                   ...                            ...         ...
# 515        Rita Olivares        Rita_Olivares@gmail.com     Febrero
# 516         Cleto Montes         Cleto_Montes@gmail.com     Febrero
# 517      Marino Castilla      Marino_Castilla@gmail.com     Febrero
# 518  Estefanía Valcárcel  Estefanía_Valcárcel@gmail.com     Febrero
# 519       Noemí Vilanova       Noemí_Vilanova@gmail.com     Febrero
#
#     Fecha_comienzo    Campus       tipo_proyecto resultado
# 0       18/09/2023    Madrid        Proyecto_HLF      Apto
# 1       18/09/2023    Madrid        Proyecto_HLF      Apto
# 2       18/09/2023    Madrid        Proyecto_HLF      Apto
# 3       18/09/2023    Madrid        Proyecto_HLF      Apto
# 4       18/09/2023    Madrid        Proyecto_HLF      Apto
# ..             ...       ...                 ...       ...
# 515     12/02/2024  Valencia  Proyecto_FullStack      Apto
# 516     12/02/2024  Valencia  Proyecto_FullStack      Apto
# 517     12/02/2024  Valencia  Proyecto_FullStack   No Apto
# 518     12/02/2024  Valencia  Proyecto_FullStack      Apto
# 519     12/02/2024  Valencia  Proyecto_FullStack      Apto
#
# [260 rows x 7 columns]

# %% [markdown]
# ### 3. LOOKUP TABLES
#    - df_campus         (Madrid, Valencia...)
#    - df_tipo_proyecto  (HLF, EDA, BBDD...)
#    - df_promocion      (Septiembre, Febrero)
#    - df_modalidad      (Presencial, Online)
#    - df_vertical       (DS, FS)
#    - df_rol            (Teacher, Teacher Assistant)

# %%
# in our df_melted each campus is repeated multiple times
# we create a new dataframe (campus) and with "drop_duplicates" we keep only 1 campus of each (Madrid & Valencia)
# we use reset_index because, for example, if "Valencia" was originally on row 515, it's index would still be 515
# drop = True: with this we're telling the system "don't keep the old index, throw it away"
# index + 1 because Postgre SQL expects IDs to start at 1

df_campus = df_melted[["Campus"]].drop_duplicates().reset_index(drop = True)
df_campus = df_campus.rename(columns={"Campus": "campus"})
df_campus["id"] = df_campus.index + 1

print(df_campus)
# Out:
#      campus  id
# 0    Madrid   1
# 1  Valencia   2

# %%
# same thing as before
# we assign each project and ID to only have one of each

df_tipo_proyecto = df_melted[["tipo_proyecto"]].drop_duplicates().reset_index(drop = True)

df_tipo_proyecto["id"] = df_tipo_proyecto.index + 1

df_tipo_proyecto = df_tipo_proyecto.rename(columns =  {"id": "tipo_proyecto_id"})

print(df_tipo_proyecto)
# Out:
#          tipo_proyecto  tipo_proyecto_id
# 0         Proyecto_HLF                 1
# 1         Proyecto_EDA                 2
# 2        Proyecto_BBDD                 3
# 3          Proyecto_ML                 4
# 4  Proyecto_Deployment                 5
# 5      Proyecto_WebDev                 6
# 6    Proyecto_FrontEnd                 7
# 7     Proyecto_Backend                 8
# 8       Proyecto_React                 9
# 9   Proyecto_FullStack                10

# %%
# same thing as before
# we assign each promotion and ID to only have one of each
# 09/04: modified column name to match PostgreSQL 

df_promocion = df_melted[["Promoción"]].drop_duplicates().reset_index(drop = True)
df_promocion = df_promocion.rename(columns = {"Promoción": "promocion"})
df_promocion["id"] = df_promocion.index + 1

print(df_promocion)
# Out:
#     promocion  id
# 0  Septiembre   1
# 1     Febrero   2

# %%
# same thing as before
# we assign each modalidad (presencial or online) and ID to only have one of each
# 09/04: modified column name to match PostgreSQL 

df_modalidad = df_faculty[["Modalidad"]].drop_duplicates().reset_index(drop = True)
df_modalidad = df_modalidad.rename(columns = {"Modalidad": "modalidad"})
df_modalidad["id"] = df_modalidad.index + 1

print(df_modalidad)
# Out:
#     modalidad  id
# 0  Presencial   1
# 1      Online   2

# %%
# same thing as before
# we assign each vertical (DS or FS) and ID to only have one of each
# 09/04: modified column name to match PostgreSQL 

df_vertical = df_faculty[["Vertical"]].drop_duplicates().reset_index(drop = True)
df_vertical = df_vertical.rename(columns = {"Vertical": "vertical"})
df_vertical["id"] = df_vertical.index + 1

print(df_vertical)
# Out:
#   vertical  id
# 0       DS   1
# 1       FS   2

# %%
# same thing as before
# we assign each role (teacher or TA) and ID to only have one of each
# 09/04: modified column name to match PostgreSQL 

df_rol = df_faculty[["Rol"]].drop_duplicates().reset_index(drop = True)
df_rol = df_rol.rename(columns = {"Rol": "rol"})
df_rol["id"] = df_rol.index + 1

print(df_rol)
# Out:
#   rol  id
# 0  TA   1
# 1  LI   2

# %% [markdown]
# ### DATAFRAMES CREADOS
#
# ✅ df_campus
#
# ✅ df_tipo_proyecto
#
# ✅ df_promocion
#
# ✅ df_modalidad
#
# ✅ df_vertical
#
# ✅ df_rol

# %% [markdown]
# ### 4. Add id to df_students
#    - df_students → add estudiante_id to the dataframe

# %%
df_students["id"] = df_students.index + 1

df_students = df_students.rename(columns = {"id": "estudiante_id"})

print(df_students[["estudiante_id", "Nombre"]].head())
# Out:
#    estudiante_id            Nombre
# 0              1      Jafet Casals
# 1              2  Jorge Manzanares
# 2              3     Onofre Adadia
# 3              4      Merche Prada
# 4              5      Pilar Abella

# %% [markdown]
# ### 5. MAIN TABLES
#    - df_students → merged with campus + promocion → kept Nombre, Email, campus_id, promocion_id
#    - df_faculty  → merged with rol + campus + vertical → kept Nombre, rol_id, campus_id, vertical_id

# %%
# we now need to create the main entity tables (students and faculty)
# let's start with estudiante
# how = left -> we want to keep all of the columns from df_students and match campus where possible
# 09/04: df_students = "Campus" & df_campus = "campus" 
    # left_on = "look in df_students" // right_on = "look in df_campus"

df_students = df_students.merge(df_campus, left_on = "Campus", right_on = "campus", how = "left")

print(df_students[["Nombre", "Campus", "id"]].head())
# Out:
#              Nombre  Campus  id
# 0      Jafet Casals  Madrid   1
# 1  Jorge Manzanares  Madrid   1
# 2     Onofre Adadia  Madrid   1
# 3      Merche Prada  Madrid   1
# 4      Pilar Abella  Madrid   1

# %%
print(df_students.columns.tolist())

print(df_campus.columns.tolist())
# Out:
# ['Nombre', 'Email', 'Promoción', 'Fecha_comienzo', 'Campus', 'Proyecto_HLF', 'Proyecto_EDA', 'Proyecto_BBDD', 'Proyecto_ML', 'Proyecto_Deployment', 'Proyecto_WebDev', 'Proyecto_FrontEnd', 'Proyecto_Backend', 'Proyecto_React', 'Proyecto_FullStack', 'estudiante_id', 'campus', 'id']
# ['campus', 'id']

# %%
# id is too generic // we'll change it to campus_id

df_students = df_students.rename(columns = {"id": "campus_id"})

# %%
# same as before but instead of campus we now merge with promocion

df_students = df_students.merge(df_promocion, left_on = "Promoción", right_on = "promocion", how="left")

print(df_students[["Nombre", "promocion", "id"]].head())
# Out:
#              Nombre   promocion  id
# 0      Jafet Casals  Septiembre   1
# 1  Jorge Manzanares  Septiembre   1
# 2     Onofre Adadia  Septiembre   1
# 3      Merche Prada  Septiembre   1
# 4      Pilar Abella  Septiembre   1

# %%
# id is too generic // we'll change it to promocio_id

df_students = df_students.rename(columns = {"id": "promocion_id"})

# %%
df_faculty.head(1)
# Out:
#       Nombre Rol Vertical   Promocion  Campus   Modalidad
# 0  Noa Yáñez  TA       DS  Septiembre  Madrid  Presencial

# %%
print(df_faculty.columns.tolist())
# Out:
# ['Nombre', 'Rol', 'Vertical', 'Promocion', 'Campus', 'Modalidad']

# %%
print("df_rol:", df_rol.columns.tolist())
print("df_campus:", df_campus.columns.tolist())
print("df_vertical:", df_vertical.columns.tolist())
print("df_modalidad:", df_modalidad.columns.tolist())
print("df_promocion:", df_promocion.columns.tolist())
# Out:
# df_rol: ['rol', 'id']
# df_campus: ['campus', 'id']
# df_vertical: ['vertical', 'id']
# df_modalidad: ['modalidad', 'id']
# df_promocion: ['promocion', 'id']

# %%
# same as we did before with students
# but now we merge df_faculty with df_rol, df_campus and df_vertical
# since "id" is too generic for each merger // we modify each "id" depending on their "parent" df
# 09/04: had to modify column names for it to match with the tables created in PostgreSQL 

df_faculty = df_faculty.merge(df_rol[["rol", "id"]], left_on = "Rol", right_on = "rol", how = "left")
df_faculty = df_faculty.drop(columns = ["rol"]).rename(columns = {"id": "rol_id"})

df_faculty = df_faculty.merge(df_campus[["campus", "id"]], left_on = "Campus", right_on = "campus", how = "left")
df_faculty = df_faculty.drop(columns = ["campus"]).rename(columns = {"id": "campus_id"})

df_faculty = df_faculty.merge(df_vertical[["vertical", "id"]], left_on = "Vertical", right_on = "vertical", how = "left")
df_faculty = df_faculty.drop(columns = ["vertical"]).rename(columns = {"id": "vertical_id"})

df_faculty = df_faculty[["Nombre", "rol_id", "campus_id", "vertical_id"]]
df_faculty = df_faculty.rename(columns = {"Nombre": "nombre"})
df_faculty["id"] = df_faculty.index + 1

print(df_faculty.columns.tolist())
# Out:
# ['nombre', 'rol_id', 'campus_id', 'vertical_id', 'id']

# %% [markdown]
# ### 5. NEXT UP
#    - Build df_calificacion from df_melted
#    - Connect to PostgreSQL and insert everything

# %%
# our df_melted currently looks like this 
# we need to replace the text values with their IDs so that PostgreSQL may read it correctly

df_melted.head(1)
# Out:
#          Nombre                   Email   Promoción Fecha_comienzo  Campus  \
# 0  Jafet Casals  Jafet_Casals@gmail.com  Septiembre     18/09/2023  Madrid
#
#   tipo_proyecto resultado
# 0  Proyecto_HLF      Apto

# %%
# here we merge df_melted and df_students to get "estudiante_id"
# we only merge on "Nombre" (to match on) and "estudiante_id" to keep
# everything else is uncessary

df_calificacion = df_melted.merge(df_students[["Nombre", "estudiante_id"]], on = "Nombre", how = "left")

# %%
# same as before but in this case we merge df_califacion and df_tipo_proyecto to get ·proyecto_id"

df_calificacion = df_calificacion.merge(df_tipo_proyecto, on = "tipo_proyecto", how = "left")

# %%
# lastly we modify our df_califacion to only keep what we need

df_calificacion = df_calificacion[["estudiante_id", "tipo_proyecto_id", "resultado"]]

# %%
# double check to see if our df is consisted of pure IDs except the "resultado" column

print(df_calificacion.head(10))
# Out:
#    estudiante_id  tipo_proyecto_id resultado
# 0              1                 1      Apto
# 1              2                 1      Apto
# 2              3                 1      Apto
# 3              4                 1      Apto
# 4              5                 1      Apto
# 5              6                 1      Apto
# 6              7                 1   No Apto
# 7              8                 1   No Apto
# 8              9                 1      Apto
# 9             10                 1      Apto

# %%
# one last check to make sure that we no longer have null values 

print(df_calificacion.shape)

print(df_calificacion.isnull().sum())
# Out:
# (260, 3)
# estudiante_id       0
# tipo_proyecto_id    0
# resultado           0
# dtype: int64

# %% [markdown]
# ### RECAP
#
# ✅ df_campus          (2 rows)
#
# ✅ df_vertical        (2 rows)
#
# ✅ df_modalidad       (2 rows)
#
# ✅ df_promocion       (2 rows)
#
# ✅ df_rol             (2 rows)
#
# ✅ df_tipo_proyecto   (10 rows)
#
# ✅ df_students        (52 rows)
#
# ✅ df_faculty         (10 rows)
#
# ✅ df_calificacion    (260 rows)

# %%
df_tipo_proyecto
# Out:
#          tipo_proyecto  tipo_proyecto_id
# 0         Proyecto_HLF                 1
# 1         Proyecto_EDA                 2
# 2        Proyecto_BBDD                 3
# 3          Proyecto_ML                 4
# 4  Proyecto_Deployment                 5
# 5      Proyecto_WebDev                 6
# 6    Proyecto_FrontEnd                 7
# 7     Proyecto_Backend                 8
# 8       Proyecto_React                 9
# 9   Proyecto_FullStack                10

# %%
df_calificacion.head(1)
# Out:
#    estudiante_id  tipo_proyecto_id resultado
# 0              1                 1      Apto

# %%
df_campus
# Out:
#      campus  id
# 0    Madrid   1
# 1  Valencia   2

# %%
df_rol
# Out:
#   rol  id
# 0  TA   1
# 1  LI   2

# %%
df_vertical
# Out:
#   vertical  id
# 0       DS   1
# 1       FS   2

# %%
df_promocion
# Out:
#     promocion  id
# 0  Septiembre   1
# 1     Febrero   2

# %%
df_faculty
# Out:
#                nombre  rol_id  campus_id  vertical_id  id
# 0           Noa Yáñez       1          1            1   1
# 1   Saturnina Benitez       1          1            1   2
# 2          Anna Feliu       1          1            2   3
# 3       Rosalva Ayuso       1          2            2   4
# 4    Ana Sofía Ferrer       1          2            2   5
# 5     Angélica Corral       1          1            2   6
# 6         Ariel Lledó       1          1            1   7
# 7         Mario Prats       2          2            2   8
# 8   Luis Ángel Suárez       2          1            2   9
# 9  María Dolores Diaz       2          1            1  10

# %%
df_promocion
# Out:
#     promocion  id
# 0  Septiembre   1
# 1     Febrero   2

# %%
import psycopg2
from sqlalchemy import create_engine

# create connection to Render

engine = create_engine("postgresql://project_sql_db_user:cz2pLEhSjr7zJm97cJyKeeMoT4eTbKha@dpg-d7bmknsvjg8s73bvvo9g-a.oregon-postgres.render.com/project_sql_db")

# %%
# push df_campus into its table

df_campus.to_sql("campus", engine, if_exists = "append", index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# OperationalError: connection to server at "dpg-d7bmknsvjg8s73bvvo9g-a.oregon-postgres.render.com" (35.227.164.209), port 5432 failed: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 3
#       1 # push df_campus into its table
# ----> 3 df_campus.to_sql("campus", engine, if_exists = "append", index = False)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\sql.py:840, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     835 elif not isinstance(frame, DataFrame):
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
# --> 840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#    (...)    852         **engine_kwargs,
#     853     )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     902     raise ImportError(
#     903         f"Using URI string without version '{VERSIONS['sqlalchemy']}' or newer "
#     904         "of 'sqlalchemy' installed."
#     905     )
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\sql.py:1649, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1647     self.exit_stack.callback(con.dispose)
#    1648 if isinstance(con, Engine):
# -> 1649     con = self.exit_stack.enter_context(con.connect())
#    1650 if need_transaction and not con.in_transaction():
#    1651     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# KeyboardInterrupt:

# %%
df_promocion
# Out:
#     promocion  id
# 0  Septiembre   1
# 1     Febrero   2

# %%
# df_promocion data push to PostgreSQL

df_promocion.to_sql("promocion", engine, if_exists = "append", index = False)
# Out:
# 2

# %%
# df_modalidad data push to PostgreSQL

df_modalidad.to_sql("modalidad", engine, if_exists = "append", index = False)
# Out:
# 2

# %%
# df_rol data push to PostgreSQL

df_rol.to_sql("rol", engine, if_exists = "append", index = False)
# Out:
# 2

# %%
# df_vertical data push to PostgreSQL

df_vertical.to_sql("vertical", engine, if_exists = "append", index = False)
# Out:
# 2

# %%
# df_tipo_proyecto data push to PostgreSQL

df_tipo_proyecto.to_sql("tipo_proyecto", engine, if_exists = "append", index = False)
# Out:
# 10

# %%
# 1st we drop all of the project columns because the now live in the calificacion dataframe
# 2nd we rename the columns for the match the ones in PostgreSQL 

df_students = df_students[["estudiante_id", "Nombre", "Email", "Fecha_comienzo", "campus_id", "promocion_id"]]
df_students = df_students.rename(columns = {
    "Nombre": "nombre",
    "Email": "email",
    "Fecha_comienzo": "fecha_comienzo",
    "estudiante_id": "id"
})

print(df_students.columns.tolist())
# Out:
# ['id', 'nombre', 'email', 'fecha_comienzo', 'campus_id', 'promocion_id']

# %%
# PostgreSQL expects dates in YYY-MM-DD but our CSV has them in DD/MM/YYYY
# pd.to_datetime converts the string into a proper datetime object
# dayfirst = True -> parameter that tells panda that in our date string, the first number is the day and not the month

df_students["fecha_comienzo"] = pd.to_datetime(df_students["fecha_comienzo"], dayfirst = True)
print(df_students["fecha_comienzo"].head())
# Out:
# 0   2023-09-18
# 1   2023-09-18
# 2   2023-09-18
# 3   2023-09-18
# 4   2023-09-18
# Name: fecha_comienzo, dtype: datetime64[us]

# %%
# df_students data push to PostgreSQL

df_students.to_sql("estudiante", engine, if_exists = "append", index = False)
# Out:
# 52

# %%
# df_faculty was missing an ID column
# renamed the "Nombre" column for it to match with PostgreSQL

df_faculty["id"] = df_faculty.index + 1
df_faculty = df_faculty.rename(columns={"Nombre": "nombre"})
df_faculty
# Out:
#                nombre Rol Vertical   Promocion    Campus   Modalidad  id
# 0           Noa Yáñez  TA       DS  Septiembre    Madrid  Presencial   1
# 1   Saturnina Benitez  TA       DS  Septiembre    Madrid  Presencial   2
# 2          Anna Feliu  TA       FS  Septiembre    Madrid  Presencial   3
# 3       Rosalva Ayuso  TA       FS  Septiembre  Valencia  Presencial   4
# 4    Ana Sofía Ferrer  TA       FS     Febrero  Valencia  Presencial   5
# 5     Angélica Corral  TA       FS     Febrero    Madrid  Presencial   6
# 6         Ariel Lledó  TA       DS  Septiembre    Madrid  Presencial   7
# 7         Mario Prats  LI       FS     Febrero  Valencia      Online   8
# 8   Luis Ángel Suárez  LI       FS  Septiembre    Madrid      Online   9
# 9  María Dolores Diaz  LI       DS  Septiembre    Madrid      Online  10

# %%
# last column names check before pushing to PostgreSQL

print(df_faculty.columns.tolist())
# Out:
# ['nombre', 'Rol', 'Vertical', 'Promocion', 'Campus', 'Modalidad', 'id']

# %%
# df_faculty data push to PostgreSQL

df_faculty.to_sql("faculty", engine, if_exists="append", index=False)
# Out:
# 10

# %%
# last column names check before pushing to PostgreSQL
#  
print(df_calificacion.columns.tolist())
# Out:
# ['estudiante_id', 'tipo_proyecto_id', 'resultado']

# %%
# df_califiacion data push to PostgreSQL

df_calificacion.to_sql("calificacion", engine, if_exists="append", index=False)
# Out:
# 260
